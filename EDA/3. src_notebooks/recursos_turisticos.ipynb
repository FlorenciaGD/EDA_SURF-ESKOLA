# %%
import requests
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\Users\\Flore\\Desktop\\EDA_SURF ESKOLA\\atracciones_recursos_turisticos.csv"
recursos = pd.read_csv(path, sep=";")
recursos
# Out:
#     CATEGORIA        CCAA   PROVINCIA VALORACION_POR_CATEGORIA  \
# 0      Activo  Naturaleza   Andalucia                  Almeria
# 1      Activo  Naturaleza   Andalucia                    Cadiz
# 2      Activo  Naturaleza   Andalucia                  Cordoba
# 3      Activo  Naturaleza   Andalucia                  Granada
# 4      Activo  Naturaleza   Andalucia                   Huelva
# ..        ...         ...         ...                      ...
# 486      Vida    Nocturna        Pais                    Vasco
# 487      Vida    Nocturna        Pais                    Vasco
# 488      Vida    Nocturna        Pais                    Vasco
# 489      Vida    Nocturna  Principado                       de
# 490      Vida    Nocturna      Region                       de
#
#     TOTAL_OPINIONES_CATEGORIA VALORACION_GENERAL Unnamed: 6 Unnamed: 7  \
# 0                        4,43              16866       4,26        NaN
# ...

# %%
recursos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 491 entries, 0 to 490
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CATEGORIA                  491 non-null    object
#  1   CCAA                       491 non-null    object
#  2   PROVINCIA                  491 non-null    object
#  3   VALORACION_POR_CATEGORIA   491 non-null    object
#  4   TOTAL_OPINIONES_CATEGORIA  491 non-null    object
#  5   VALORACION_GENERAL         491 non-null    object
#  6   Unnamed: 6                 408 non-null    object
#  7   Unnamed: 7                 268 non-null    object
#  8   Unnamed: 8                 157 non-null    object
#  9   Unnamed: 9                 57 non-null     object
#  10  Unnamed: 10                11 non-null     object
#  11  Unnamed: 11                1 non-null      object
#  12  Err:501                    0 non-null      float64
# dtypes: float64(1), object(12)
# ...
