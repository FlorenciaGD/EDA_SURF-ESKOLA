# %%
import pandas as pd
import unicodedata
import numpy as np


path = "C:\\Users\\Flore\Desktop\\EDA_SURF ESKOLA\\conectividad_aerea_busquedas_momento_busqueda.csv"
busqueda = pd.read_csv(path, sep=";")
busqueda
# Out:
#         A�O  MES PAIS_ORIGEN          CIUDAD_DESTINO    TIPO_ORIGEN  \
# 0      2024    1  Afganist�n        Alacant/Alicante  Internacional
# 1      2024    1  Afganist�n               Barcelona  Internacional
# 2      2024    1  Afganist�n                  Bilbao  Internacional
# 3      2024    1  Afganist�n           Fuerteventura  Internacional
# 4      2024    1  Afganist�n                   Ibiza  Internacional
# ...     ...  ...         ...                     ...            ...
# 62997  2024   12    Zimbabwe  Santiago de Compostela  Internacional
# 62998  2024   12    Zimbabwe                 Sevilla  Internacional
# 62999  2024   12    Zimbabwe                Tenerife  Internacional
# 63000  2024   12    Zimbabwe                Valverde  Internacional
# 63001  2024   12    Zimbabwe                Val�ncia  Internacional
#
#        BUSQUEDAS ANTELACION ESTANCIA_MEDIA VARIACION_INTERANUAL_BUSQUEDAS
# 0              3       31,0            6,0                          -25,0
# ...

# %%
busqueda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63002 entries, 0 to 63001
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   A�O                             63002 non-null  int64
#  1   MES                             63002 non-null  int64
#  2   PAIS_ORIGEN                     63002 non-null  object
#  3   CIUDAD_DESTINO                  63002 non-null  object
#  4   TIPO_ORIGEN                     63002 non-null  object
#  5   BUSQUEDAS                       63002 non-null  int64
#  6   ANTELACION                      63002 non-null  object
#  7   ESTANCIA_MEDIA                  63002 non-null  object
#  8   VARIACION_INTERANUAL_BUSQUEDAS  63002 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 4.3+ MB

# %%
busqueda.describe()
# Out:
#            A�O           MES     BUSQUEDAS
# count  63002.0  63002.000000  6.300200e+04
# mean    2024.0      6.400003  5.207915e+04
# std        0.0      3.436967  1.703656e+06
# min     2024.0      1.000000  1.000000e+00
# 25%     2024.0      3.000000  7.000000e+00
# 50%     2024.0      6.000000  4.900000e+01
# 75%     2024.0      9.000000  6.290000e+02
# max     2024.0     12.000000  1.152123e+08
